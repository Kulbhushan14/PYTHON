# %% [markdown]
# ## Python Pandas with HTML

# %%
import pandas as pd

# %%
html=pd.read_html("https://en.wikipedia.org/wiki/Mobile_country_code")

# %%
## finding the talbe by indexing
html[0].head()
# Out:
#    MCC  MNC Brand      Operator       Status Bands (MHz)  \
# 0    1    1  TEST  Test network  Operational         any
# 1    1    1  TEST  Test network  Operational         any
# 2  999   99   NaN  Internal use  Operational         any
# 3  999  999   NaN  Internal use  Operational         any
#
#                               References and notes
# 0                                              NaN
# 1                                              NaN
# 2  Internal use in private networks, no roaming[6]
# 3  Internal use in private networks, no roaming[6]

# %%
html[1].head()
# Out:
#    Mobile country code                                    Country ISO 3166  \
# 0                  289                                 A Abkhazia    GE-AB
# 1                  412                                Afghanistan       AF
# 2                  276                                    Albania       AL
# 3                  603                                    Algeria       DZ
# 4                  544  American Samoa (United States of America)       AS
#
#                              Mobile network codes National MNC authority  \
# 0        List of mobile network codes in Abkhazia                    NaN
# 1     List of mobile network codes in Afghanistan                    NaN
# 2         List of mobile network codes in Albania                    NaN
# 3         List of mobile network codes in Algeria                    NaN
# 4  List of mobile network codes in American Samoa                    NaN
#
#                     Remarks
# 0  MCC is not listed by ITU
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN

# %%
html=pd.read_html("https://en.wikipedia.org/wiki/Economy_of_the_United_States",match="Government debt")

# %%
html[0]
# Out:
#                                                     0  \
# 0   New York City, the world’s principal fintech a...
# 1                                            Currency
# 2                                         Fiscal year
# 3                                 Trade organizations
# 4                                       Country group
# 5                                          Statistics
# 6                                          Population
# 7                                                 GDP
# 8                                            GDP rank
# 9                                          GDP growth
# 10                                     GDP per capita
# 11                                GDP per capita rank
# 12                                      GDP by sector
# 13                                   GDP by component
# 14                                    Inflation (CPI)
# 15                      Population below poverty line
# 16                                   Gini coefficient
# 17                            Human Development Index
# 18                                        Labor force
# 19                          Labor force by occupation
# 20                                       Unemployment
# 21                               Average gross salary
# 22                                 Average net salary
# 23                                    Main industries
# 24                                           External
# 25                                            Exports
# 26                                       Export goods
# 27                               Main export partners
# 28                                            Imports
# 29                                       Import goods
# 30                               Main import partners
# 31                                          FDI stock
# 32                                    Current account
# 33                                Gross external debt
# 34                                    Public finances
# 35                                    Government debt
# 36                                     Budget balance
# 37                                           Revenues
# 38                                           Expenses
# 39                                       Economic aid
# 40                                      Credit rating
# 41                                   Foreign reserves
# 42  Main data source: CIA World Fact Book All valu...
#
#                                                     1
# 0   New York City, the world’s principal fintech a...
# 1          United States dollar (USD) US Dollar Index
# 2                            October 1 – September 30
# 3         WTO, G-20, G7, OECD, USMCA, APEC and others
# 4   Developed/Advanced[4] High-income economy[5] D...
# 5                                          Statistics
# 6                    340,332,281 (August 30, 2023)[7]
# 7   $27.97 trillion (nominal; 2024 est.)[8] $27.97...
# 8                 1st (nominal; 2023) 2nd (PPP; 2023)
# 9    2.1% (2022)[9]  2.1% (2023f)[9]  1.5% (2024f)[9]
# 10  $83,060 (nominal; 2024)[8] $83,060 (PPP; 2024)[8]
# 11               7th (nominal; 2023) 10th (PPP; 2023)
# 12  Agriculture: 0.9% Industry: 18.9% Services: 80...
# 13  Household consumption: 68.4% Government consum...
# 14                                      3% (2023)[10]
# 15            11.6% (2021)[11]  38 million (2021)[11]
# 16  49.4 high (2021, USCB)[12]  43.4 medium (2017,...
# 17  0.921 very high (2021)[14] (21st)  0.819 very ...
# 18  161,200,000 (2023)[16] 62.4% employment rate (...
# 19  Agriculture: 1.0% Industry: 19% Services: 80% ...
# 20  3.4% (January 2023)[16]  10.4% youth unemploym...
# 21                 $5,407 / €5,052 monthly[18] (2022)
# 22             $4,066 / €3,799 monthly[19][20] (2022)
# 23  Petroleumsteelmotor vehiclesaerospacetelecommu...
# 24                                           External
# 25                         $3.053 trillion (2023)[21]
# 26  Agricultural products 10.7%Fuels and mining pr...
# 27  European Union(-) 18.3% Canada(-) 17.5% Mexico...
# 28                         $3.827 trillion (2023)[21]
# 29  Agricultural products 10.5%Fuels and mining pr...
# 30  European Union(+) 23.6% Mexico(+) 15.4% China(...
# 31  Inward: $367 billion (2021)[25]  Outward: $403...
# 32  −$985.25 billion (2022)[26]  −3.93% of GDP (20...
# 33                            $27 trillion (2023)[27]
# 34                                    Public finances
# 35         $30.568 trillion  122.1% of GDP (2022)[26]
# 36                            –5.5% of GDP (2022)[28]
# 37            $8.371 trillion[26] 33.4% of GDP (2022)
# 38            $9.379 trillion[26] 37.4% of GDP (2022)
# 39              donor: ODA, $35.26 billion (2017)[29]
# 40  Standard & Poor's:[30][31] AA+ (Domestic) AA+ ...
# 41                            $217 billion (2023)[35]
# 42  Main data source: CIA World Fact Book All valu...

# %%
html=pd.read_html("https://en.wikipedia.org/wiki/Minnesota",match="Average daily maximum and minimum temperatures for selected cities in Minnesota")

# %%
html[0]
# Out:
#               Location July (°F) July (°C) January (°F) January (°C)
# 0          Minneapolis     83/64     28/18         23/7       −4/−13
# 1           Saint Paul     83/63     28/17         23/6       −5/−14
# 2            Rochester     82/63     28/17         23/3       −5/−16
# 3               Duluth     76/55     24/13         19/1       −7/−17
# 4            St. Cloud     81/58     27/14        18/−1       −7/−18
# 5              Mankato     86/62     30/16         23/3       −5/−16
# 6  International Falls     77/52     25/11        15/−6       −9/−21

# %%
type(html[0])
# Out:
# pandas.core.frame.DataFrame

# %%
html[0].to_html("demo.html")
